# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"C:\Users\91781\Downloads\IMDb_Dataset.csv")

# %%
data.shape
# Out:
# (255, 9)

# %%
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
data.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %%
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   400.000000   400.000000  400.000000          400.000000
# mean      7.110250  2015.150000   66.898750          116.334750
# std       0.932251    13.470194   15.312006           21.369757
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2010.750000   57.750000          101.000000
# 50%       7.100000  2023.000000   66.900000          116.000000
# 75%       7.700000  2024.000000   77.000000          124.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               400 non-null    object
#  1   IMDb Rating         400 non-null    float64
#  2   Year                400 non-null    int64
#  3   Certificates        400 non-null    object
#  4   Genre               400 non-null    object
#  5   Director            400 non-null    object
#  6   Star Cast           400 non-null    object
#  7   MetaScore           400 non-null    float64
#  8   Duration (minutes)  400 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
data.shape[0]
# Out:
# 400

# %%
data.shape[1]
# Out:
# 9

# %%
data.index
# Out:
# RangeIndex(start=0, stop=400, step=1)

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
data.head(3)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
#
#   Certificates   Genre               Director  \
# 0            R  Action           Ridley Scott
# 1        PG-13  Action  Christopher McQuarrie
# 2        PG-13  Action            Zack Snyder
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# 2        Zack SnyderKurt JohnstadShay Hatten       35.0               122.0

# %%
data.isna().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
data.isnull().any()
# Out:
# Title                 False
# IMDb Rating           False
# Year                  False
# Certificates          False
# Genre                 False
# Director              False
# Star Cast             False
# MetaScore             False
# Duration (minutes)    False
# dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 391                                 Anyone But You          6.1  2023
# 394                              Kinds of Kindness          7.0  2024
# 395                            Mother of the Bride          4.8  2024
# 397                                The Idea of You          6.4  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data.MetaScore.mean()
# Out:
# 67.61333333333333

# %%
data.MetaScore.median()
# Out:
# 67.0

# %%
data.drop(columns = "IMDb Rating").head(3)
# Out:
#                                            Title  Year Certificates   Genre  \
# 0                                      Gladiator  2000            R  Action
# 1  Mission: Impossible - Dead Reckoning Part One  2023        PG-13  Action
# 2           Rebel Moon - Part Two: The Scargiver  2024        PG-13  Action
#
#                 Director                                  Star Cast  \
# 0           Ridley Scott  David FranzoniJohn LoganWilliam Nicholson
# 1  Christopher McQuarrie         Tom CruiseHayley AtwellVing Rhames
# 2            Zack Snyder        Zack SnyderKurt JohnstadShay Hatten
#
#    MetaScore  Duration (minutes)
# 0       67.0               155.0
# 1       81.0               163.0
# 2       35.0               122.0

# %%
data.value_counts()
# Out:
# Title                       IMDb Rating  Year  Certificates  Genre      Director           Star Cast                                               MetaScore  Duration (minutes)
# 10 Things I Hate About You  7.3          1999  PG-13         Comedy     Gil Junger         Heath LedgerJulia StilesJoseph Gordon-Levitt            70.0       97.0                  1
# Talk to Me                  7.1          2022  R             Horror     Danny Philippou    Ari McCarthyHamish PhillipsKit Erhart-Bruce             76.0       95.0                  1
# Sing                        7.1          2016  PG            Animation  Garth Jennings     Matthew McConaugheyReese WitherspoonSeth MacFarlane     59.0       108.0                 1
# Sing 2                      7.3          2021  PG            Animation  Garth Jennings     Matthew McConaugheyReese WitherspoonScarlett Johansson  49.0       110.0                 1
# ...

# %%
data.MetaScore.value_counts()
# Out:
# MetaScore
# 66.9     36
# 81.0      8
# 73.0      8
# 74.0      8
# 71.0      7
#          ..
# 26.0      1
# 100.0     1
# 56.0      1
# 50.0      1
# 42.0      1
# Name: count, Length: 66, dtype: int64

# %%
data.rename(columns={"Duration (minutes)":"TimeDuration"},inplace =True)

# %%
data.head(2)
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
#
#   Certificates   Genre               Director  \
# 0            R  Action           Ridley Scott
# 1        PG-13  Action  Christopher McQuarrie
#
#                                    Star Cast  MetaScore  TimeDuration
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0         155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0         163.0

# %%
data[data["Year"]>2000]
# Out:
#                                              Title  IMDb Rating  Year  \
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# 7                                       Inside Out          8.1  2015
# ..                                             ...          ...   ...
# 391                                 Anyone But You          6.1  2023
# 394                              Kinds of Kindness          7.0  2024
# 395                            Mother of the Bride          4.8  2024
# 397                                The Idea of You          6.4  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 1          PG-13     Action  Christopher McQuarrie
# ...

# %%
data[data["Genre"] == "Biography"]
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 125               Goodfellas          8.7  1990            R  Biography
# 127  The Wolf of Wall Street          8.2  2013            R  Biography
# 389                Unfrosted          5.5  2024        PG-13  Biography
#
#             Director                                 Star Cast  MetaScore  \
# 125  Martin Scorsese           Nicholas PileggiMartin Scorsese       92.0
# 127  Martin Scorsese  Leonardo DiCaprioJonah HillMargot Robbie       75.0
# 389   Jerry Seinfeld    Jerry SeinfeldSpike FerestenAndy Robin       42.0
#
#      TimeDuration
# 125         145.0
# 127         180.0
# 389          97.0

# %%
sorted_df = data.sort_values(by='TimeDuration', ascending=False)
sorted_df.head(5)
# Out:
#                           Title  IMDb Rating  Year Certificates      Genre  \
# 131  Killers of the Flower Moon          7.6  2023            R      Crime
# 104                      Animal          6.2  2023    Not Rated     Action
# 103              The Green Mile          8.6  1999            R      Crime
# 203           Avengers: Endgame          8.4  2019        PG-13     Action
# 127     The Wolf of Wall Street          8.2  2013            R  Biography
#
#                 Director                                      Star Cast  \
# 131      Martin Scorsese  Leonardo DiCaprioRobert De NiroLily Gladstone
# 104  Sandeep Reddy Vanga  Suresh BandaruSaurabh GuptaPranay Reddy Vanga
# 103       Frank Darabont      Tom HanksMichael Clarke DuncanDavid Morse
# 203        Anthony Russo      Christopher MarkusStephen McFeelyStan Lee
# 127      Martin Scorsese       Leonardo DiCaprioJonah HillMargot Robbie
#
#      MetaScore  TimeDuration
# 131       89.0         206.0
# ...

# %%
data[data["Director"].isin(["George Stevens","Steve McQueen"])]
# Out:
# Empty DataFrame
# Columns: [Title, IMDb Rating, Year, Certificates, Genre, Director, Star Cast, MetaScore, TimeDuration]
# Index: []

# %%
data[data.index.isin(range(100,200))]
# Out:
#                          Title  IMDb Rating  Year Certificates   Genre  \
# 100                Taxi Driver          8.2  1976            R   Crime
# 101          Kill Bill: Vol. 1          8.2  2003            R  Action
# 102          We're the Millers          7.0  2013            R  Comedy
# 103             The Green Mile          8.6  1999            R   Crime
# 104                     Animal          6.2  2023    Not Rated  Action
# ..                         ...          ...   ...          ...     ...
# 194  Late Night with the Devil          7.1  2023            R  Horror
# 196              The Substance          8.0  2024            R   Drama
# 197                    Abigail          6.7  2024            R  Horror
# 198   The Strangers: Chapter 1          5.0  2024            R  Horror
# 199    Beetlejuice Beetlejuice          7.1  2024            R  Comedy
#
#                     Director                                      Star Cast  \
# ...

# %%
data[data.index == 100]
# Out:
#            Title  IMDb Rating  Year Certificates  Genre         Director  \
# 100  Taxi Driver          8.2  1976            R  Crime  Martin Scorsese
#
#                                        Star Cast  MetaScore  TimeDuration
# 100  Robert De Niro,Jodie Foster,Cybill Shepherd       94.0         114.0

# %%
data.rename(columns={"IMDb Rating":"IMDbRating"},inplace =True)

# %%
data.head(2)
# Out:
#                                            Title  IMDbRating  Year  \
# 0                                      Gladiator         8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One         7.7  2023
#
#   Certificates   Genre               Director  \
# 0            R  Action           Ridley Scott
# 1        PG-13  Action  Christopher McQuarrie
#
#                                    Star Cast  MetaScore  TimeDuration
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0         155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0         163.0

# %%
Genre=['Adventure', 'Biography', 'Documentary', 'Action', 'Animation']
x = data["Genre"]
y = data["MetaScore"]
plt.xlabel('Genre',fontsize=26)
plt.ylabel('MetaScore', fontsize=25)
plt.bar(x,y)
# Out:
# <BarContainer object of 255 artists>

# %%
sns.displot(data["TimeDuration"])

# %%
sns.displot(data[('IMDbRating')])

# %%
sns.histplot(data["IMDbRating"])
# Out:
# <Axes: xlabel='IMDbRating', ylabel='Count'>

# %%
data.tail()
# Out:
#                    Title  IMDbRating  Year Certificates   Genre  \
# 391       Anyone But You         6.1  2023            R  Comedy
# 394    Kinds of Kindness         7.0  2024            R  Comedy
# 395  Mother of the Bride         4.8  2024        TV-PG  Comedy
# 397      The Idea of You         6.4  2024            R  Comedy
# 399         The Fall Guy         7.1  2024        PG-13  Action
#
#               Director                                     Star Cast  \
# 391         Will Gluck                       Ilana WolpertWill Gluck
# 394   Yorgos Lanthimos             Efthimis FilippouYorgos Lanthimos
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  TimeDuration
# 391       52.0         103.0
# 394       72.0         164.0
# 395       39.0          88.0
# 397       67.0         115.0
# ...

# %%
Z = data['IMDbRating'].head(5)
plt.pie(Z, labels=Z, autopct='%1.1f%%', startangle=150,shadow=True,radius=1,pctdistance =0.75)
plt.title("Pie chart for year and Genre")
plt.show()

# %%
dt=data[data.index.isin(range(2,10))]
sns.countplot(x ='Certificates', data=dt)
# Out:
# <Axes: xlabel='Certificates', ylabel='count'>

# %%
sns.boxplot(data["Year"])
# Out:
# <Axes: ylabel='Year'>
