# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset= pd.read_csv(r"C:\Users\91781\Downloads\crime_data.csv (2).zip")

# %%
dataset.head()
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0  2022-04-12  2020-10-01    00:01    19    Mission         1     821
# 1  2023-01-05  2020-02-01    08:00     2    Rampart         2     812
# 2  2023-03-21  2020-03-15    12:00    19    Mission         2     812
# 3  2023-06-04  2020-07-01    12:00    20    Olympic         2     812
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4             CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
#
#   Vict Descent                                   Premis Desc  \
# ...

# %%
dataset.tail()
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 230540                                 BRANDISH WEAPON        38        M
# 230541                                         ROBBERY        23        F
# 230542                                         ROBBERY        65        F
# 230543               INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent             Premis Desc  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
dataset.describe()
# Out:
#                 AREA       Part 1-2         Crm Cd       Vict Age
# count  230545.000000  230545.000000  230545.000000  230545.000000
# mean       10.466881       1.544991     508.044629      34.451513
# std         6.225582       0.497973     240.542475      18.003355
# min         1.000000       1.000000     110.000000      -2.000000
# 25%         5.000000       1.000000     230.000000      23.000000
# 50%        11.000000       2.000000     624.000000      33.000000
# 75%        16.000000       2.000000     626.000000      46.000000
# max        21.000000       2.000000     956.000000      99.000000

# %%
dataset.isna().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
dataset.isna().any()
# Out:
# Date Rptd       False
# DATE OCC        False
# TIME OCC        False
# AREA            False
# AREA NAME       False
# Part 1-2        False
# Crm Cd          False
# Crm Cd Desc     False
# Vict Age        False
# Vict Sex        False
# Vict Descent    False
# Premis Desc     False
# Weapon Desc     False
# Status Desc     False
# LOCATION        False
# dtype: bool

# %%
dataset.shape
# Out:
# (230545, 15)

# %%
dataset=dataset.drop_duplicates()
dataset
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
# ...

# %%
dataset.AREA.mean()
# Out:
# 10.46649864389929

# %%
dataset.AREA.median()
# Out:
# 11.0

# %%
dataset[dataset.AREA == 10]
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 24      2022-11-14  2020-07-24    15:00    10  West Valley         1     761
# 25      2022-07-05  2020-03-01    12:00    10  West Valley         2     626
# 66      2022-01-29  2020-08-01    15:00    10  West Valley         2     812
# 85      2022-01-21  2020-01-01    00:01    10  West Valley         2     930
# 117     2023-02-22  2020-10-27    19:45    10  West Valley         1     121
# ...            ...         ...      ...   ...          ...       ...     ...
# 230376  2023-11-05  2023-11-05    00:20    10  West Valley         2     624
# 230439  2023-07-10  2023-07-10    18:55    10  West Valley         1     230
# 230456  2023-03-25  2023-03-25    18:00    10  West Valley         1     230
# 230469  2023-07-01  2023-07-01    15:30    10  West Valley         1     230
# 230532  2023-10-03  2023-10-03    02:40    10  West Valley         1     236
#
# ...

# %%
print("Duplicates in Data:")
print(dataset.duplicated().sum())
# Out:
# Duplicates in Data:
# 0

# %%
dataset[dataset["TIME OCC"].isin([10])]
# Out:
# Empty DataFrame
# Columns: [Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Part 1-2, Crm Cd, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Premis Desc, Weapon Desc, Status Desc, LOCATION]
# Index: []

# %%
dataset.value_counts()
# Out:
# Date Rptd   DATE OCC    TIME OCC  AREA  AREA NAME    Part 1-2  Crm Cd  Crm Cd Desc                                     Vict Age  Vict Sex  Vict Descent  Premis Desc             Weapon Desc                                     Status Desc  LOCATION
# 2021-01-01  2020-01-01  05:00     11    Northeast    2         626     INTIMATE PARTNER - SIMPLE ASSAULT               30        F         H             SINGLE FAMILY DWELLING  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Adult Other  3200    HURON                        ST    1
# 2023-01-14  2023-01-13  20:14     9     Van Nuys     1         210     ROBBERY                                         31        F         H             SIDEWALK                STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)  Invest Cont  6200    VAN NUYS                     BL    1
# ...

# %%
dataset.AREA.value_counts()
# Out:
# AREA
# 12    19905
# 1     18111
# 18    15179
# 6     14391
# 13    14016
# 3     13853
# 2     13167
# 20    12279
# 14    10643
# 5      9330
# 15     8997
# 4      8860
# 10     8713
# 19     8589
# 7      8444
# 21     7714
# 9      7646
# 11     7549
# 8      7470
# 17     7373
# 16     7105
# Name: count, dtype: int64

# %%
dataset[dataset.LOCATION==10]
# Out:
# Empty DataFrame
# Columns: [Date Rptd, DATE OCC, TIME OCC, AREA, AREA NAME, Part 1-2, Crm Cd, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Premis Desc, Weapon Desc, Status Desc, LOCATION]
# Index: []

# %%
dataset[dataset.index.isin(range(30,40))]
# Out:
#      Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 30  2022-05-29  2020-05-27    18:00    20      Olympic         2     626
# 31  2021-02-03  2020-12-20    14:00    12  77th Street         2     624
# 32  2022-01-28  2020-12-27    12:00     4   Hollenbeck         2     946
# 33  2022-09-28  2020-01-01    00:01    18    Southeast         1     820
# 34  2022-10-16  2020-07-11    02:00    17   Devonshire         2     624
# 35  2023-02-28  2020-02-17    12:00    19      Mission         2     627
# 36  2023-02-01  2020-04-01    23:00    13       Newton         1     210
# 37  2023-03-08  2020-03-01    12:00    11    Northeast         2     860
# 38  2023-03-03  2020-07-15    17:00    15  N Hollywood         2     946
# 39  2023-04-19  2020-06-01    08:00    12  77th Street         1     821
#
#                                           Crm Cd Desc  Vict Age Vict Sex  \
# 30                  INTIMATE PARTNER - SIMPLE ASSAULT        33        F
# ...

# %%
sns.set(color_codes=True)

# %%
sns.displot(dataset['TIME OCC'])

# %%
sns.displot(dataset['AREA'])
