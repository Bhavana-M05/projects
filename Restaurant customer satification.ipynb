# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv(r"C:\Users\91781\Downloads\restaurant_customer_satisfaction.csv")

# %%
data.shape
# Out:
# (1500, 19)

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
# 2                  0              1                     0  48.682623
# 3                  0              0                     0   7.552993
# 4                  0              0                     1  37.789041
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0              2           5               4                 0
# 1              5           5               3                 0
# 2              3           4               5                 0
# 3              4           5               1                 0
# 4              2           3               5                 0

# %%
data.tail()
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 1495                  0              1                     1   7.206275
# 1496                  0              0                     0  37.863952
# 1497                  0              1                     0   3.925785
# 1498                  1              1                     0  24.228038
# 1499                  1              1                     1  39.402163
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 1495              1           2               1                 0
# 1496              5           2               2                 0
# 1497              3           3               3                 1
# 1498              2           2               4                 1
# 1499              4           5               4                 1

# %%
data.describe()
# Out:
#         CustomerID          Age         Income  AverageSpend    GroupSize  \
# count  1500.000000  1500.000000    1500.000000   1500.000000  1500.000000
# mean   1403.500000    43.832000   85921.890000    105.659004     5.035333
# std     433.157015    14.967157   38183.051749     52.381849     2.558864
# min     654.000000    18.000000   20012.000000     10.306127     1.000000
# 25%    1028.750000    31.750000   52444.000000     62.287907     3.000000
# 50%    1403.500000    44.000000   85811.000000    104.626408     5.000000
# 75%    1778.250000    57.000000  119159.250000    148.649330     7.000000
# max    2153.000000    69.000000  149875.000000    199.973527     9.000000
#
#        OnlineReservation  DeliveryOrder  LoyaltyProgramMember     WaitTime  \
# count        1500.000000    1500.000000           1500.000000  1500.000000
# mean            0.296667       0.405333              0.480000    30.163550
# std             0.456941       0.491120              0.499766    17.214184
# min             0.000000       0.000000              0.000000     0.001380
# 25%             0.000000       0.000000              0.000000    15.235423
# 50%             0.000000       0.000000              0.000000    30.044055
# 75%             1.000000       1.000000              1.000000    45.285649
# max             1.000000       1.000000              1.000000    59.970762
#
#        ServiceRating   FoodRating  AmbianceRating  HighSatisfaction
# count    1500.000000  1500.000000     1500.000000       1500.000000
# mean        3.044000     2.997333        2.987333          0.134000
# std         1.423405     1.418920        1.450716          0.340766
# min         1.000000     1.000000        1.000000          0.000000
# 25%         2.000000     2.000000        2.000000          0.000000
# 50%         3.000000     3.000000        3.000000          0.000000
# 75%         4.000000     4.000000        4.000000          0.000000
# max         5.000000     5.000000        5.000000          1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
#  15  ServiceRating         1500 non-null   int64
#  16  FoodRating            1500 non-null   int64
#  17  AmbianceRating        1500 non-null   int64
#  18  HighSatisfaction      1500 non-null   int64
# dtypes: float64(2), int64(11), object(6)
# memory usage: 222.8+ KB

# %%
data.shape
# Out:
# (1500, 19)

# %%
data.shape[0]
# Out:
# 1500

# %%
data.shape[1]
# Out:
# 19

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1500, step=1)

# %%
data.columns
# Out:
# Index(['CustomerID', 'Age', 'Gender', 'Income', 'VisitFrequency',
#        'AverageSpend', 'PreferredCuisine', 'TimeOfVisit', 'GroupSize',
#        'DiningOccasion', 'MealType', 'OnlineReservation', 'DeliveryOrder',
#        'LoyaltyProgramMember', 'WaitTime', 'ServiceRating', 'FoodRating',
#        'AmbianceRating', 'HighSatisfaction'],
#       dtype='object')

# %%
data.head(3)
# Out:
#           0
# 0  1.747510
# 1  0.445013
# 2 -1.129832

# %%
data.isna().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# Income                  0
# VisitFrequency          0
# AverageSpend            0
# PreferredCuisine        0
# TimeOfVisit             0
# GroupSize               0
# DiningOccasion          0
# MealType                0
# OnlineReservation       0
# DeliveryOrder           0
# LoyaltyProgramMember    0
# WaitTime                0
# ServiceRating           0
# FoodRating              0
# AmbianceRating          0
# HighSatisfaction        0
# dtype: int64

# %%
data.isnull().any()
# Out:
# CustomerID              False
# Age                     False
# Gender                  False
# Income                  False
# VisitFrequency          False
# AverageSpend            False
# PreferredCuisine        False
# TimeOfVisit             False
# GroupSize               False
# DiningOccasion          False
# MealType                False
# OnlineReservation       False
# DeliveryOrder           False
# LoyaltyProgramMember    False
# WaitTime                False
# ServiceRating           False
# FoodRating              False
# AmbianceRating          False
# HighSatisfaction        False
# dtype: bool

# %%
data=data.drop_duplicates()
data
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# 1            American      Dinner          1         Casual   Dine-in
# 2            American      Dinner          6    Celebration   Dine-in
# 3              Indian       Lunch          1    Celebration   Dine-in
# 4             Chinese   Breakfast          1       Business  Takeaway
# ...               ...         ...        ...            ...       ...
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                     0              1                     1  43.523929
# 1                     0              0                     0  57.524294
# 2                     0              1                     0  48.682623
# 3                     0              0                     0   7.552993
# 4                     0              0                     1  37.789041
# ...                 ...            ...                   ...        ...
# 1495                  0              1                     1   7.206275
# 1496                  0              0                     0  37.863952
# 1497                  0              1                     0   3.925785
# 1498                  1              1                     0  24.228038
# 1499                  1              1                     1  39.402163
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0                 2           5               4                 0
# 1                 5           5               3                 0
# 2                 3           4               5                 0
# 3                 4           5               1                 0
# 4                 2           3               5                 0
# ...             ...         ...             ...               ...
# 1495              1           2               1                 0
# 1496              5           2               2                 0
# 1497              3           3               3                 1
# 1498              2           2               4                 1
# 1499              4           5               4                 1
#
# [1500 rows x 19 columns]

# %%
data.Income.mean()
# Out:
# 85921.89

# %%
data.Income.median()
# Out:
# 85811.0

# %%
data.drop(columns = "WaitTime")
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0            654   35    Male   83380         Weekly     27.829142
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 4            658   55  Female   67937        Monthly    148.084627
# ...          ...  ...     ...     ...            ...           ...
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1498        2152   24    Male   27970         Weekly    196.363626
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0             Chinese   Breakfast          3       Business  Takeaway
# 1            American      Dinner          1         Casual   Dine-in
# 2            American      Dinner          6    Celebration   Dine-in
# 3              Indian       Lunch          1    Celebration   Dine-in
# 4             Chinese   Breakfast          1       Business  Takeaway
# ...               ...         ...        ...            ...       ...
# 1495         American       Lunch          2       Business   Dine-in
# 1496          Italian       Lunch          4         Casual  Takeaway
# 1497         American       Lunch          4         Casual   Dine-in
# 1498          Italian      Dinner          6         Casual   Dine-in
# 1499          Chinese   Breakfast          4         Casual   Dine-in
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember  ServiceRating  \
# 0                     0              1                     1              2
# 1                     0              0                     0              5
# 2                     0              1                     0              3
# 3                     0              0                     0              4
# 4                     0              0                     1              2
# ...                 ...            ...                   ...            ...
# 1495                  0              1                     1              1
# 1496                  0              0                     0              5
# 1497                  0              1                     0              3
# 1498                  1              1                     0              2
# 1499                  1              1                     1              4
#
#       FoodRating  AmbianceRating  HighSatisfaction
# 0              5               4                 0
# 1              5               3                 0
# 2              4               5                 0
# 3              5               1                 0
# 4              3               5                 0
# ...          ...             ...               ...
# 1495           2               1                 0
# 1496           2               2                 0
# 1497           3               3                 1
# 1498           2               4                 1
# 1499           5               4                 1
#
# [1500 rows x 18 columns]

# %%
data["TimeOfVisit"].str.strip()
# Out:
# 0       Breakfast
# 1          Dinner
# 2          Dinner
# 3           Lunch
# 4       Breakfast
#           ...
# 1495        Lunch
# 1496        Lunch
# 1497        Lunch
# 1498       Dinner
# 1499    Breakfast
# Name: TimeOfVisit, Length: 1500, dtype: object

# %%
data[data.index.isin(range(10,20))]
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 10         664   21    Male   79249        Monthly     39.235383
# 11         665   59    Male   94208         Weekly    132.994918
# 12         666   32  Female  143471        Monthly    156.130808
# 13         667   69    Male   38433          Daily     46.136865
# 14         668   58    Male   64870        Monthly     88.939098
# 15         669   54  Female  135616         Rarely    112.007541
# 16         670   59  Female  123325         Weekly     63.939240
# 17         671   42    Male   25569        Monthly    120.390191
# 18         672   26  Female  120447         Weekly     52.110324
# 19         673   58    Male   70458         Rarely    197.370534
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 10         American   Breakfast          5       Business  Takeaway
# 11          Italian      Dinner          8         Casual   Dine-in
# 12         American   Breakfast          4         Casual  Takeaway
# 13          Italian      Dinner          4       Business  Takeaway
# 14         American       Lunch          2    Celebration   Dine-in
# 15         American       Lunch          2       Business  Takeaway
# 16          Chinese      Dinner          4         Casual  Takeaway
# 17         American      Dinner          3         Casual   Dine-in
# 18          Mexican      Dinner          1         Casual  Takeaway
# 19          Italian      Dinner          4         Casual  Takeaway
#
#     OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 10                  0              1                     0  18.948572
# 11                  0              0                     1  55.045475
# 12                  0              1                     0   4.710546
# 13                  0              1                     1  20.243443
# 14                  0              0                     1  58.271648
# 15                  1              0                     0   2.328375
# 16                  1              0                     1   2.673593
# 17                  0              0                     1  54.933784
# 18                  1              1                     1  20.726251
# 19                  1              0                     1  40.374425
#
#     ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 10              1           3               2                 0
# 11              3           3               3                 0
# 12              5           2               4                 0
# 13              1           4               3                 0
# 14              2           4               2                 0
# 15              4           4               3                 0
# 16              3           5               5                 1
# 17              1           3               3                 0
# 18              3           1               3                 0
# 19              1           2               1                 0

# %%
data['counts_per'] = data.Gender.str.split().str.get(0)

data['MealType'] = data.Gender.str.split().str.get(1) + data.Gender.str.split().str.get(2)
data[['Gender','counts_per','MealType']]
# Out:
#       Gender counts_per  MealType
# 0       Male       Male       NaN
# 1       Male       Male       NaN
# 2     Female     Female       NaN
# 3       Male       Male       NaN
# 4     Female     Female       NaN
# ...      ...        ...       ...
# 1495    Male       Male       NaN
# 1496  Female     Female       NaN
# 1497    Male       Male       NaN
# 1498    Male       Male       NaN
# 1499    Male       Male       NaN
#
# [1500 rows x 3 columns]

# %%
print(data.VisitFrequency.unique())
# Out:
# ['Weekly' 'Rarely' 'Monthly' 'Daily']

# %%
data.head()
data[data["VisitFrequency"] == "Weekly"]
data[data["Gender"] == "Female"]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 2            656   41  Female   83737         Weekly    106.693771
# 4            658   55  Female   67937        Monthly    148.084627
# 5            659   42  Female   28860        Monthly    111.064696
# 6            660   20  Female  131104         Weekly    120.236707
# 7            661   51  Female  137882         Weekly    160.979098
# ...          ...  ...     ...     ...            ...           ...
# 1485        2139   63  Female  142579         Rarely     86.874446
# 1486        2140   24  Female  109032        Monthly     15.992567
# 1488        2142   25  Female  138277        Monthly    190.013468
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1496        2150   37  Female  133506         Weekly    190.991911
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 2            American      Dinner          6    Celebration       NaN
# 4             Chinese   Breakfast          1       Business       NaN
# 5             Chinese      Dinner          8    Celebration       NaN
# 6              Indian       Lunch          6       Business       NaN
# 7             Mexican      Dinner          6       Business       NaN
# ...               ...         ...        ...            ...       ...
# 1485         American       Lunch          5    Celebration       NaN
# 1486           Indian       Lunch          6       Business       NaN
# 1488         American       Lunch          7         Casual       NaN
# 1494         American      Dinner          4       Business       NaN
# 1496          Italian       Lunch          4         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 2                     0              1                     0  48.682623
# 4                     0              0                     1  37.789041
# 5                     0              1                     1  26.853298
# 6                     0              0                     0   7.927917
# 7                     1              1                     0  56.447210
# ...                 ...            ...                   ...        ...
# 1485                  1              1                     1  49.463842
# 1486                  0              1                     1  47.889756
# 1488                  0              0                     1  51.977724
# 1494                  1              1                     1  18.134661
# 1496                  0              0                     0  37.863952
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 2                 3           4               5                 0     Female
# 4                 2           3               5                 0     Female
# 5                 4           5               3                 0     Female
# 6                 5           4               1                 0     Female
# 7                 4           3               3                 0     Female
# ...             ...         ...             ...               ...        ...
# 1485              2           3               3                 1     Female
# 1486              1           4               1                 0     Female
# 1488              3           5               5                 0     Female
# 1494              1           1               3                 1     Female
# 1496              5           2               2                 0     Female
#
# [759 rows x 20 columns]

# %%
data[data["PreferredCuisine"]== "Indian"]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 3            657   43    Male   96768         Rarely     43.508508
# 6            660   20  Female  131104         Weekly    120.236707
# 8            662   27    Male  149638         Weekly     56.558632
# 21           675   40  Female   85259        Monthly     61.456659
# 34           688   47  Female   50567          Daily     81.319539
# ...          ...  ...     ...     ...            ...           ...
# 1478        2132   42    Male  101871        Monthly    169.091936
# 1480        2134   31    Male  130898         Weekly     81.665031
# 1486        2140   24  Female  109032        Monthly     15.992567
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 3              Indian       Lunch          1    Celebration       NaN
# 6              Indian       Lunch          6       Business       NaN
# 8              Indian   Breakfast          5    Celebration       NaN
# 21             Indian      Dinner          9       Business       NaN
# 34             Indian       Lunch          1       Business       NaN
# ...               ...         ...        ...            ...       ...
# 1478           Indian      Dinner          1         Casual       NaN
# 1480           Indian   Breakfast          5       Business       NaN
# 1486           Indian       Lunch          6       Business       NaN
# 1490           Indian   Breakfast          5         Casual       NaN
# 1491           Indian       Lunch          9         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 3                     0              0                     0   7.552993
# 6                     0              0                     0   7.927917
# 8                     0              1                     0  39.568188
# 21                    0              1                     1  12.834379
# 34                    0              1                     1  10.822847
# ...                 ...            ...                   ...        ...
# 1478                  0              0                     1  49.391647
# 1480                  0              1                     0  50.949146
# 1486                  0              1                     1  47.889756
# 1490                  1              1                     0  17.525024
# 1491                  0              1                     0  55.700437
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 3                 4           5               1                 0       Male
# 6                 5           4               1                 0     Female
# 8                 2           4               5                 0       Male
# 21                3           2               5                 0     Female
# 34                4           1               4                 1     Female
# ...             ...         ...             ...               ...        ...
# 1478              5           2               1                 0       Male
# 1480              2           3               5                 1       Male
# 1486              1           4               1                 0     Female
# 1490              3           2               3                 1       Male
# 1491              3           5               1                 0       Male
#
# [296 rows x 20 columns]

# %%
data[data.Income >100000]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 6            660   20  Female  131104         Weekly    120.236707
# 7            661   51  Female  137882         Weekly    160.979098
# 8            662   27    Male  149638         Weekly     56.558632
# 9            663   32  Female  136145         Weekly     65.753455
# 12           666   32  Female  143471        Monthly    156.130808
# ...          ...  ...     ...     ...            ...           ...
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1496        2150   37  Female  133506         Weekly    190.991911
# 1497        2151   46    Male  119159        Monthly    150.088604
# 1499        2153   51    Male  148333         Weekly    171.119498
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 6              Indian       Lunch          6       Business       NaN
# 7             Mexican      Dinner          6       Business       NaN
# 8              Indian   Breakfast          5    Celebration       NaN
# 9             Italian       Lunch          9         Casual       NaN
# 12           American   Breakfast          4         Casual       NaN
# ...               ...         ...        ...            ...       ...
# 1494         American      Dinner          4       Business       NaN
# 1495         American       Lunch          2       Business       NaN
# 1496          Italian       Lunch          4         Casual       NaN
# 1497         American       Lunch          4         Casual       NaN
# 1499          Chinese   Breakfast          4         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 6                     0              0                     0   7.927917
# 7                     1              1                     0  56.447210
# 8                     0              1                     0  39.568188
# 9                     0              0                     0  20.782469
# 12                    0              1                     0   4.710546
# ...                 ...            ...                   ...        ...
# 1494                  1              1                     1  18.134661
# 1495                  0              1                     1   7.206275
# 1496                  0              0                     0  37.863952
# 1497                  0              1                     0   3.925785
# 1499                  1              1                     1  39.402163
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 6                 5           4               1                 0     Female
# 7                 4           3               3                 0     Female
# 8                 2           4               5                 0       Male
# 9                 4           3               1                 0     Female
# 12                5           2               4                 0     Female
# ...             ...         ...             ...               ...        ...
# 1494              1           1               3                 1     Female
# 1495              1           2               1                 0       Male
# 1496              5           2               2                 0     Female
# 1497              3           3               3                 1       Male
# 1499              4           5               4                 1       Male
#
# [611 rows x 20 columns]

# %%
data[data["PreferredCuisine"].isin(["Indian","American"])]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 1            655   19    Male   43623         Rarely    115.408622
# 2            656   41  Female   83737         Weekly    106.693771
# 3            657   43    Male   96768         Rarely     43.508508
# 6            660   20  Female  131104         Weekly    120.236707
# 8            662   27    Male  149638         Weekly     56.558632
# ...          ...  ...     ...     ...            ...           ...
# 1490        2144   20    Male  106717         Rarely    105.323720
# 1491        2145   47    Male   90569         Weekly    101.312053
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1495        2149   39    Male  114857        Monthly    163.015254
# 1497        2151   46    Male  119159        Monthly    150.088604
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 1            American      Dinner          1         Casual       NaN
# 2            American      Dinner          6    Celebration       NaN
# 3              Indian       Lunch          1    Celebration       NaN
# 6              Indian       Lunch          6       Business       NaN
# 8              Indian   Breakfast          5    Celebration       NaN
# ...               ...         ...        ...            ...       ...
# 1490           Indian   Breakfast          5         Casual       NaN
# 1491           Indian       Lunch          9         Casual       NaN
# 1494         American      Dinner          4       Business       NaN
# 1495         American       Lunch          2       Business       NaN
# 1497         American       Lunch          4         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 1                     0              0                     0  57.524294
# 2                     0              1                     0  48.682623
# 3                     0              0                     0   7.552993
# 6                     0              0                     0   7.927917
# 8                     0              1                     0  39.568188
# ...                 ...            ...                   ...        ...
# 1490                  1              1                     0  17.525024
# 1491                  0              1                     0  55.700437
# 1494                  1              1                     1  18.134661
# 1495                  0              1                     1   7.206275
# 1497                  0              1                     0   3.925785
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 1                 5           5               3                 0       Male
# 2                 3           4               5                 0     Female
# 3                 4           5               1                 0       Male
# 6                 5           4               1                 0     Female
# 8                 2           4               5                 0       Male
# ...             ...         ...             ...               ...        ...
# 1490              3           2               3                 1       Male
# 1491              3           5               1                 0       Male
# 1494              1           1               3                 1     Female
# 1495              1           2               1                 0       Male
# 1497              3           3               3                 1       Male
#
# [566 rows x 20 columns]

# %%
data[data["Gender"].isin(["Female"])]
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 2            656   41  Female   83737         Weekly    106.693771
# 4            658   55  Female   67937        Monthly    148.084627
# 5            659   42  Female   28860        Monthly    111.064696
# 6            660   20  Female  131104         Weekly    120.236707
# 7            661   51  Female  137882         Weekly    160.979098
# ...          ...  ...     ...     ...            ...           ...
# 1485        2139   63  Female  142579         Rarely     86.874446
# 1486        2140   24  Female  109032        Monthly     15.992567
# 1488        2142   25  Female  138277        Monthly    190.013468
# 1494        2148   25  Female  142332         Weekly    128.626784
# 1496        2150   37  Female  133506         Weekly    190.991911
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 2            American      Dinner          6    Celebration       NaN
# 4             Chinese   Breakfast          1       Business       NaN
# 5             Chinese      Dinner          8    Celebration       NaN
# 6              Indian       Lunch          6       Business       NaN
# 7             Mexican      Dinner          6       Business       NaN
# ...               ...         ...        ...            ...       ...
# 1485         American       Lunch          5    Celebration       NaN
# 1486           Indian       Lunch          6       Business       NaN
# 1488         American       Lunch          7         Casual       NaN
# 1494         American      Dinner          4       Business       NaN
# 1496          Italian       Lunch          4         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 2                     0              1                     0  48.682623
# 4                     0              0                     1  37.789041
# 5                     0              1                     1  26.853298
# 6                     0              0                     0   7.927917
# 7                     1              1                     0  56.447210
# ...                 ...            ...                   ...        ...
# 1485                  1              1                     1  49.463842
# 1486                  0              1                     1  47.889756
# 1488                  0              0                     1  51.977724
# 1494                  1              1                     1  18.134661
# 1496                  0              0                     0  37.863952
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 2                 3           4               5                 0     Female
# 4                 2           3               5                 0     Female
# 5                 4           5               3                 0     Female
# 6                 5           4               1                 0     Female
# 7                 4           3               3                 0     Female
# ...             ...         ...             ...               ...        ...
# 1485              2           3               3                 1     Female
# 1486              1           4               1                 0     Female
# 1488              3           5               5                 0     Female
# 1494              1           1               3                 1     Female
# 1496              5           2               2                 0     Female
#
# [759 rows x 20 columns]

# %%
data[data["Age"] > 50].head(10)
# Out:
#     CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 4          658   55  Female   67937        Monthly    148.084627
# 7          661   51  Female  137882         Weekly    160.979098
# 11         665   59    Male   94208         Weekly    132.994918
# 13         667   69    Male   38433          Daily     46.136865
# 14         668   58    Male   64870        Monthly     88.939098
# 15         669   54  Female  135616         Rarely    112.007541
# 16         670   59  Female  123325         Weekly     63.939240
# 19         673   58    Male   70458         Rarely    197.370534
# 23         677   51    Male   40666         Weekly     54.668755
# 26         680   51    Male  105609         Rarely     12.690321
#
#    PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 4           Chinese   Breakfast          1       Business       NaN
# 7           Mexican      Dinner          6       Business       NaN
# 11          Italian      Dinner          8         Casual       NaN
# 13          Italian      Dinner          4       Business       NaN
# 14         American       Lunch          2    Celebration       NaN
# 15         American       Lunch          2       Business       NaN
# 16          Chinese      Dinner          4         Casual       NaN
# 19          Italian      Dinner          4         Casual       NaN
# 23          Mexican       Lunch          6         Casual       NaN
# 26          Chinese      Dinner          6       Business       NaN
#
#     OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 4                   0              0                     1  37.789041
# 7                   1              1                     0  56.447210
# 11                  0              0                     1  55.045475
# 13                  0              1                     1  20.243443
# 14                  0              0                     1  58.271648
# 15                  1              0                     0   2.328375
# 16                  1              0                     1   2.673593
# 19                  1              0                     1  40.374425
# 23                  0              1                     1  24.855225
# 26                  1              0                     0  24.074858
#
#     ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 4               2           3               5                 0     Female
# 7               4           3               3                 0     Female
# 11              3           3               3                 0       Male
# 13              1           4               3                 0       Male
# 14              2           4               2                 0       Male
# 15              4           4               3                 0     Female
# 16              3           5               5                 1     Female
# 19              1           2               1                 0       Male
# 23              2           2               3                 0       Male
# 26              5           1               5                 0       Male

# %%
min_value = data["FoodRating"].min()
max_value = data["FoodRating"].max()

print("minimum rating of food : ",min_value)
print("maximum rating of food : ",max_value)
# Out:
# minimum rating of food :  1
# maximum rating of food :  5

# %%
data.sort_values(["Income"],ascending=[False]) 
print(data)
# Out:
#       CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 861         1515   40    Male  149875         Weekly    116.279303
# 1122        1776   45  Female  149856         Rarely     44.519643
# 1272        1926   31  Female  149807         Rarely    167.184428
# 570         1224   32  Female  149728        Monthly    156.869604
# 884         1538   56    Male  149720         Weekly     51.888609
# ...          ...  ...     ...     ...            ...           ...
# 978         1632   34    Male   20381         Weekly     12.836971
# 280          934   46    Male   20312          Daily     46.101730
# 522         1176   55  Female   20150         Rarely    114.734866
# 323          977   57    Male   20093         Weekly    166.165108
# 811         1465   49  Female   20012         Weekly    158.638696
#
#      PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 861            Indian       Lunch          8    Celebration       NaN
# 1122          Italian       Lunch          2         Casual       NaN
# 1272          Italian   Breakfast          8       Business       NaN
# 570            Indian      Dinner          8         Casual       NaN
# 884           Chinese      Dinner          9       Business       NaN
# ...               ...         ...        ...            ...       ...
# 978           Chinese   Breakfast          1    Celebration       NaN
# 280          American   Breakfast          4    Celebration       NaN
# 522           Mexican       Lunch          4    Celebration       NaN
# 323           Italian   Breakfast          8         Casual       NaN
# 811           Italian      Dinner          5         Casual       NaN
#
#       OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 861                   1              1                     0  36.272264
# 1122                  1              0                     0  33.253632
# 1272                  1              0                     1  48.621336
# 570                   0              1                     1  33.472604
# 884                   0              1                     0   1.773040
# ...                 ...            ...                   ...        ...
# 978                   1              1                     1  10.870001
# 280                   0              0                     0   0.674031
# 522                   1              0                     0  40.511062
# 323                   0              0                     1   5.024798
# 811                   0              1                     1  17.193218
#
#       ServiceRating  FoodRating  AmbianceRating  HighSatisfaction counts_per
# 861               3           4               3                 0       Male
# 1122              5           4               3                 0     Female
# 1272              3           4               4                 0     Female
# 570               2           1               1                 0     Female
# 884               2           4               1                 0       Male
# ...             ...         ...             ...               ...        ...
# 978               3           1               2                 0       Male
# 280               1           2               3                 0       Male
# 522               3           5               4                 0     Female
# 323               3           3               3                 0       Male
# 811               2           3               5                 0     Female
#
# [1500 rows x 20 columns]

# %%
highest_Income = data["Income"].max()
print("The highest Income :",highest_Income)
# Out:
# The highest Income : 149875

# %%
plt.style.use('bmh')
data= pd.read_csv(r"C:\Users\91781\Downloads\restaurant_customer_satisfaction.csv")

# %%
x = data['ServiceRating']
y = data['AmbianceRating']
plt.xlabel('ServiceRating',fontsize=24)
plt.ylabel('AmbianceRating', fontsize=24)
plt.bar(x,y)
# Out:
# <BarContainer object of 1500 artists>

# %%
sns.set(color_codes=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            1500 non-null   int64
#  1   Age                   1500 non-null   int64
#  2   Gender                1500 non-null   object
#  3   Income                1500 non-null   int64
#  4   VisitFrequency        1500 non-null   object
#  5   AverageSpend          1500 non-null   float64
#  6   PreferredCuisine      1500 non-null   object
#  7   TimeOfVisit           1500 non-null   object
#  8   GroupSize             1500 non-null   int64
#  9   DiningOccasion        1500 non-null   object
#  10  MealType              1500 non-null   object
#  11  OnlineReservation     1500 non-null   int64
#  12  DeliveryOrder         1500 non-null   int64
#  13  LoyaltyProgramMember  1500 non-null   int64
#  14  WaitTime              1500 non-null   float64
#  15  ServiceRating         1500 non-null   int64
#  16  FoodRating            1500 non-null   int64
#  17  AmbianceRating        1500 non-null   int64
#  18  HighSatisfaction      1500 non-null   int64
# dtypes: float64(2), int64(11), object(6)
# memory usage: 222.8+ KB

# %%
sns.displot(data['ServiceRating'])

# %%
data = np.random.randn(100)
da = pd.Series(data,name="DeliveryOrder")
plot = sns.displot(set,kde=True)
plt.show()

# %%
res = sns.lineplot(x="PreferredCuisine", y="GroupSize", data=data)
plt.show()

# %%
res = sns.catplot(x="FoodRating", y="DeliveryOrder", data=data)
plt.show()

# %%
res = sns.displot(x="GroupSize", y="Gender", data=data) 
plt.show()

# %%
res = sns.violinplot(x=data['Age'])
plt.show()

# %%
res = sns.boxplot(x=data['AmbianceRating'])
plt.show()

# %%
res = sns.countplot(x=data['MealType'])
plt.show()

# %%
res = sns.pointplot(x=data['DiningOccasion'], y=data['Income'])
plt.show()

# %%
data.head()
# Out:
#    CustomerID  Age  Gender  Income VisitFrequency  AverageSpend  \
# 0         654   35    Male   83380         Weekly     27.829142
# 1         655   19    Male   43623         Rarely    115.408622
# 2         656   41  Female   83737         Weekly    106.693771
# 3         657   43    Male   96768         Rarely     43.508508
# 4         658   55  Female   67937        Monthly    148.084627
#
#   PreferredCuisine TimeOfVisit  GroupSize DiningOccasion  MealType  \
# 0          Chinese   Breakfast          3       Business  Takeaway
# 1         American      Dinner          1         Casual   Dine-in
# 2         American      Dinner          6    Celebration   Dine-in
# 3           Indian       Lunch          1    Celebration   Dine-in
# 4          Chinese   Breakfast          1       Business  Takeaway
#
#    OnlineReservation  DeliveryOrder  LoyaltyProgramMember   WaitTime  \
# 0                  0              1                     1  43.523929
# 1                  0              0                     0  57.524294
# 2                  0              1                     0  48.682623
# 3                  0              0                     0   7.552993
# 4                  0              0                     1  37.789041
#
#    ServiceRating  FoodRating  AmbianceRating  HighSatisfaction
# 0              2           5               4                 0
# 1              5           5               3                 0
# 2              3           4               5                 0
# 3              4           5               1                 0
# 4              2           3               5                 0

# %%
Average_Spend= data.groupby('Gender')['AverageSpend'].sum().sort_values(ascending=False)
plt.figure(figsize=(3,4))
plt.pie(Average_Spend, labels=Visit_Frequency.index, autopct='%1.1f%%')
plt.title('AverageSpend')
plt.axis('equal')
plt.show()

# %%
sns.boxplot(data["WaitTime"])
# Out:
# <Axes: ylabel='WaitTime'>

# %%
data1=data.head(20)
sns.pairplot(data1[['Age', 'GroupSize', 'WaitTime', 'FoodRating','LoyaltyProgramMember',]])

# %%
sns.histplot(data["WaitTime"])
# Out:
# <Axes: xlabel='WaitTime', ylabel='Count'>
